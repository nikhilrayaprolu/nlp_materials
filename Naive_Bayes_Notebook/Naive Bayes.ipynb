# %%
import nltk
import os

# %%
corpus_files = sorted(os.listdir('corpora'))

# %%
def tokenise(corpus):
    return [s.split(' ') for s in corpus.split("\n")]

def get_unigrams(corpus):
    unigrams = {}
    for sentence in corpus:
        for word in sentence:
            word = word.lower()
            if word not in unigrams:
                unigrams[word] = 0
            unigrams[word] += 1
    return unigrams

def sort_dict(d, reverse = True):
    return sorted(d.items(), key = lambda x : x[1], reverse = reverse)

# %%
corpora = {f : tokenise(open('corpora/'+f).read()) for f in corpus_files}
all_unigrams = {author : get_unigrams(corpus) for author, corpus in corpora.items()}

for author, corpus in corpora.items():
    print(author, len(corpus), len(all_unigrams[author]))
# Out:
# twain.txt 12329 13838
# tolstoy.txt 66056 40132
# dickens.txt 20423 21142
# doyle.txt 13053 14544
# austen.txt 13428 13128

# %%
def merge_unigrams(unigrams):
    all_words = set([word for author in unigrams for word in unigrams[author]])
    for word in all_words:
        for author in unigrams:
            if word not in unigrams[author]:
                unigrams[author][word] = 0
    print("Total unique words", len(all_words))
    return all_words

# %%
from ipy_table import *
all_words = merge_unigrams(all_unigrams)
utable = [(word, [all_unigrams[author][word] for author in all_unigrams]) for word in all_words]
sorted_utable = sorted(utable, key = lambda x: sum(x[1]), reverse=True)
make_table(sorted_utable[:10])
# Out:
# Total unique words 66481
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td>the</td><td>[4862,&nbsp8239,&nbsp5704,&nbsp4479,&nbsp34258]</td></tr><tr><td>and</td><td>[6107,&nbsp6746,&nbsp2882,&nbsp3398,&nbsp21396]</td></tr><tr><td>to</td><td>[2911,&nbsp5063,&nbsp2719,&nbsp4169,&nbsp16500]</td></tr><tr><td></td><td>[2736,&nbsp4456,&nbsp3146,&nbsp2777,&nbsp16769]</td></tr><tr><td>of</td><td>[1746,&nbsp4481,&nbsp2756,&nbsp3680,&nbsp14904]</td></tr><tr><td>a</td><td>[2949,&nbsp4022,&nbsp2648,&nbsp1982,&nbsp10388]</td></tr><tr><td>in</td><td>[1387,&nbsp2948,&nbsp1757,&nbsp1890,&nbsp8733]</td></tr><tr><td>i</td><td>[2476,&nbsp5674,&nbsp2533,&nbsp1740,&nbsp3226]</td></tr><tr><td>he</td><td>[1444,&nbsp2026,&nbsp1278,&nbsp1248,&nbsp9298]</td></tr><tr><td>was</td><td>[1942,&nbsp2691,&nbsp1370,&nbsp1797,&nbsp7200]</td></tr></table>

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import *
init_notebook_mode(connected=True)
sorted_utable = sorted_utable[:500]
authors = list(all_unigrams.keys())
get_v_for_auth = lambda x : list(zip(*list(zip(*sorted_utable))[1]))[authors.index(x)]

iplot([ 
    Bar({"x" : list(zip(*sorted_utable))[0], "y": get_v_for_auth(author)}, name=author) for author in all_unigrams
])
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="b440b6f9-10c3-4676-aa29-c0daaae4d81f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b440b6f9-10c3-4676-aa29-c0daaae4d81f", [{"name": "twain.txt", "type": "bar", "y": [4862, 6107, 2911, 2736, 1746, 2949, 1387, 2476, 1444, 1942, 909, 545, 553, 450, 1478, 541, 407, 1050, 154, 298, 837, 777, 789, 426, 234, 361, 389, 172, 749, 399, 478, 352, 175, 9, 616, 708, 93, 260, 314, 377, 383, 307, 131, 369, 720, 494, 145, 702, 357, 42, 465, 653, 376, 280, 153, 65
", "such", "than", "come", "before", "should", "has", "our", "pierre", "time", "am", "must", "over", "him,", "two", "never", "looked", "him.", "go", "without", "made", "got", "came", "it,", "other", "it.", "much", "can", "just", "where", "thought", "first", "upon", "himself", "being", "don\u2019t", "its", "chapter", "think", "took", "get", "good", "still", "these", "say", "own", "saw", "long", "those", "might", "felt", "always", "same", "may", "seemed", "back", "most", "left", "nothing", "me,", "though", "make", "began", "face", "every", "young", "having", "take", "way", "because", "tell", "something", "even", "miss", "told", "again", "asked", "heard", "look", "whole", "eyes", "away", "quite", "us", "off", "going", "princess", "put", "last", "men", "let", "while", "andrew", "through", "under", "nat\u00e1sha", "day", "looking", "french", "shall", "done", "give", "head", "soon", "and,", "ever", "another", "knew", "\u201cand", "\u201cyou", "great", "round", "right", "people", "turned" ...

# %%
def convert_to_probs(unigrams):
    uprobs = {}
    for author in unigrams:
        V = len(list(unigrams[author].keys()))
        N = sum(list(unigrams[author].values()))
        uprobs[author] = {}
        for word in unigrams[author]:
            #uprobs[author][word] = unigrams[author][word] / float(N)
            uprobs[author][word] = (unigrams[author][word] + 1)/ (float(N) + V)
    return uprobs

# %%
uprobs = convert_to_probs(all_unigrams)
uptable = [(word, [uprobs[author][word] for author in uprobs]) for word in all_words]
sorted_uptable = sorted(uptable, key = lambda x: sum(x[1]), reverse=True)
make_table(sorted_uptable[:10])
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td>the</td><td>[0.026510897652561684,&nbsp0.052741937222022944,&nbsp0.031893235073269285,&nbsp0.03220252878753669,&nbsp0.023110652566417332]</td></tr><tr><td>and</td><td>[0.03329807996336557,&nbsp0.03294081061150719,&nbsp0.026114521485357752,&nbsp0.016273425152404607,&nbsp0.017534175909208152]</td></tr><tr><td>to</td><td>[0.01587491958960716,&nbsp0.025403389068583453,&nbsp0.019600405632407242,&nbsp0.01535335290133213,&nbsp0.021511477946866135]</td></tr><tr><td></td><td>[0.014920897979654808,&nbsp0.025817516191754715,&nbsp0.017250988922519566,&nbsp0.017763603522239782,&nbsp0.014330668042300748]</td></tr><tr><td>of</td><td>[0.009523861443352922,&nbsp0.022946337438169588,&nbsp0.017347752378445748,&nbsp0.015562203657710544,&nbsp0.018988908950219242]</td></tr><tr><td>a</td><td>[0.016082078567768245,&nbsp0.015993928188201535,&nbsp0.015571175327641061,&nbsp0.014952585233687062,&nbsp0.010229558937322672]</td></tr><tr><td>i</td><td>[0.013503494444868454,&nbsp0.004967985972021017,&nbsp0.02196530449524311,&nbsp0.0143034545044028,&nbsp0.008981171008511736]</td></tr><tr><td>in</td><td>[0.00756675425493638,&nbsp0.013446045701776129,&nbsp0.011414217261052321,&nbsp0.00992323323549334,&nbsp0.009754965179262316]</td></tr><tr><td>was</td><td>[0.010592365646499558,&nbsp0.011085982951510179,&nbsp0.01041948893413118,&nbsp0.0077387672160758635,&nbsp0.009275212793396957]</td></tr><tr><td>he</td><td>[0.007877492722178005,&nbsp0.014315866611039183,&nbsp0.007845581006494764,&nbsp0.007219462632648453,&nbsp0.006443126128449833]</td></tr></table>

# %%
sorted_uptable = sorted_uptable[:500]
authors = list(all_unigrams.keys())
get_v_for_auth = lambda x : list(zip(*list(zip(*sorted_uptable))[1]))[authors.index(x)]

iplot([ 
    Bar({"x" : list(zip(*sorted_uptable))[0], "y": get_v_for_auth(author)}, name=author) for author in all_unigrams
])
# Out:
# <div id="7adbcb4a-7591-468c-8f96-4a3bf57a51ad" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("
.0011012135154878594, 0.0006596377988813415, 0.0008504421208718122, 0.0008722483290992945, 0.0004906396851183532, 0.0005942191741988945, 0.00013083724936489418, 9.267638496680005e-05, 0.00016354656170611774, 5.451552056870591e-06, 4.3612416454964726e-05, 0.0011393743798859535, 0.0009267638496680005, 0.0007250564235637886, 2.7257760284352954e-05, 0.0002998353631278825, 0.0007850234961893651, 0.0010630526510897653, 0.0003488993316397178, 0.0005178974454027062, 0.0010957619634309889, 0.0007359595276775298, 0.0007577657359050121, 0.0004252210604359061, 0.00016899811376298833, 0.0004197695083790355, 0.0007795719441324945, 0.00 ...

# %%
def sentence_prob(sentence):
    probs = []
    for author in uprobs:
        p = 1.0
        for word in sentence:
            p *= uprobs[author][word]
        probs += [(author, p)]
    return probs

# %%
sentence = 'this is a bright day'.split(' ')
sprobs = sentence_prob(sentence)
print(sprobs)
iplot([ 
    Scatter({"x" : list(zip(*sprobs))[0], "y": list(zip(*sprobs))[1]})
])

iplot([ 
    Bar({"x" : sentence, "y": [uprobs[author][w] for w in sentence]}, name=author) for author in all_unigrams
])
# Out:
# [('twain.txt', 2.2651895590185623e-16), ('tolstoy.txt', 1.072347368624062e-14), ('dickens.txt', 4.255603163224632e-15), ('doyle.txt', 4.698404021611878e-15), ('austen.txt', 3.930048527783163e-16)]
# <div id="d96e3db3-6c8d-4580-89d7-21a082e78ae4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d96e3db3-6c8d-4580-89d7-21a082e78ae4", [{"x": ["twain.txt", "tolstoy.txt", "dickens.txt", "doyle.txt", "austen.txt"], "type": "scatter", "y": [2.2651895590185623e-16, 1.072347368624062e-14, 4.255603163224632e-15, 4.698404021611878e-15, 3.930048527783163e-16]}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
# <div id="a7af28ad-5131-46f3-81f2-0bdd67400b8f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a7af28ad-5131-46f3-81f2-0bdd67400b8f", [{"name": "twain.txt", "type": "bar", "y": [0.0014228550868432242, 0.001281114733364589, 0.016082078567768245, 2.1806208227482363e-05, 0.0003543508836965884], "x": ["this", "is", "a", "bright", "day"]}, {"name": "dickens.txt", "type": "bar", "y": [0.002655189230614409, 0.0021404076450871256, 0.015571175327641061, 0.00011611614711141731, 0.0004141475913640551], "x": ["this", "is", "a", "bright", "day"]}, {"name": "doyle.txt", "type": "bar", "y": [0.0026360352223978325, 0.0061131180853465795, 0.014952585233687062, 6.773538044705351e-05, 0.0002878753668999774], "x": ["this", "is", "a", "bright", "day"]}, {"name": "austen.txt", "type": "bar", "y": [0.0021356719112716016, 0.004224916172298168, 0.010229558937322672, 1.0317255610007738e-05, 0.00041269022440030954], "x": ["this", "is", "a", "bright", "day"]}, {"name": "tolstoy.txt", "type": "bar", "y": [0.0028265330785964015, 0.004678558837611364, 0.015993928188201535, 8.621233790925843e-05, 0.00058809130502387], "x": ["this", "is", "a", "bright", "day"]}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# ## We have
# $$ P(word\,|\,class) = \frac{c(word\,in\,class)}{c(all\,words\,in\,that\,class)}$$
# ## What we need
# $$ P(class\,|\,word) $$
# $$ \rightarrow \frac{P(word\,|\,class) * P(class)}{P(word)} $$
# ## How to choose a class ?
# $$class = argmax_i\,P(class_i\,|\,word)$$
# $$ \rightarrow argmax_i \, \frac{P(word\,|\,class_i) * P(class_i)}{P(word)} $$
# $$ \rightarrow argmax_i \, P(word\,|\,class_i) * P(class_i) $$

# %%
def class_prob(corpora):
    probs = {}
    for author, corpus in corpora.items():
        probs[author] = sum([len(x) for x in corpus])
    M = sum(list(probs.values()))
    return {a : p/float(M) for a,p in probs.items()}

# %%
cprobs = class_prob(corpora)

# %%
sorted_cprobs = sort_dict(cprobs)
iplot([ 
    Scatter({"x" : list(zip(*sorted_cprobs))[0], "y": list(zip(*sorted_cprobs))[1]})
])
# Out:
# <div id="576e7199-f14d-48c4-9a94-7187805bce43" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("576e7199-f14d-48c4-9a94-7187805bce43", [{"x": ["tolstoy.txt", "dickens.txt", "austen.txt", "twain.txt", "doyle.txt"], "type": "scatter", "y": [0.5160164961591561, 0.16981220574179617, 0.11271991928917838, 0.10350189387234947, 0.09794948493751991]}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
def nbestimate(sentence):
    probs = []
    sprob = 0
    for author in uprobs:
        p = 1.0
        for word in sentence:
            p *= uprobs[author][word] 
        sprob += p
        probs += [(author, p * cprobs[author])]
    return probs, sprob

# %%
nbprobs, sprob = nbestimate(sentence)

iplot([ 
    Bar({"x" : list(zip(*sprobs))[0], "y": list(zip(*sprobs))[1]}),
    Bar({"x" : list(zip(*nbprobs))[0], "y": [i for i in list(zip(*nbprobs))[1]]})
])
nbmax = max(nbprobs, key= lambda x : x[1])
smax = max(sprobs, key= lambda x : x[1])
print(nbmax, smax)
# Out:
# <div id="0e1cbf7a-2015-4bb3-929a-08a5e6628db2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0e1cbf7a-2015-4bb3-929a-08a5e6628db2", [{"x": ["twain.txt", "tolstoy.txt", "dickens.txt", "doyle.txt", "austen.txt"], "type": "bar", "y": [2.2651895590185623e-16, 1.072347368624062e-14, 4.255603163224632e-15, 4.698404021611878e-15, 3.930048527783163e-16]}, {"x": ["twain.txt", "tolstoy.txt", "dickens.txt", "doyle.txt", "austen.txt"], "type": "bar", "y": [2.3445140933829332e-17, 5.533489318228795e-15, 7.226533599089397e-16, 4.602062539452556e-16, 4.429947528542724e-17]}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
# ('tolstoy.txt', 5.533489318228795e-15) ('tolstoy.txt', 1.072347368624062e-14)

# %%
import random
nprobs = {}
for auth, c in corpora.items():
    clen = len(corpora[auth])
    rsentence = corpora[auth][random.randrange(clen)]
    rsentence = [w.lower() for w in rsentence]
    print(auth, rsentence)
    nbprobs = nbestimate(rsentence)
    nprobs[auth] = nbprobs
    iplot([ 
        Scatter({"x" : list(zip(*nbprobs))[0], "y": list(zip(*nbprobs))[1]}, name=auth) 
    ])
# iplot([ 
#     Bar({"x" : list(zip(*D))[0], "y": list(zip(*D))[1]}, name=auth) for auth, D in nprobs.items()
# ])
# Out:
# tolstoy.txt ['ask', 'forgiveness.']
# <div id="915ffc54-0e18-44d8-a4d3-5e9663fe6f03" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("915ffc54-0e18-44d8-a4d3-5e9663fe6f03", [{"y": [5.364248490026242e-10, 2.0786524558132357e-11, 8.791097071112384e-12, 7.004217134603495e-12, 3.067177287109459e-11], "type": "scatter", "x": ["tolstoy.txt", "doyle.txt", "austen.txt", "twain.txt", "dickens.txt"], "name": "tolstoy.txt"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
# doyle.txt ['"what!', 'a', 'murderous', 'attack?"']
# <div id="68861f66-cc98-42e4-a179-ebe629d63921" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("68861f66-cc98-42e4-a179-ebe629d63921", [{"y": [4.1376492261882e-21, 9.901201287995408e-21, 2.267055589294501e-22, 2.9901698372435113e-22, 3.753886163656363e-21], "type": "scatter", "x": ["tolstoy.txt", "doyle.txt", "austen.txt", "twain.txt", "dickens.txt"], "name": "doyle.txt"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
# twain.txt ['and', 'this', '‘n', '‘ll', 'come', 'out', 'all', 'right.', '\xa0what’s', 'the', 'matter', 'with', '‘em?”']
# <div id="c135c0ac-7a5a-4a48-8e41-df20c23263e0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c135c0ac-7a5a-4a48-8e41-df20c23263e0", [{"y": [2.299777042898933e-51, 2.3992555904870194e-59, 2.4370949118337317e-60, 1.0801176082162791e-54, 3.4111066201835733e-56], "type": "scatter", "x": ["tolstoy.txt", "doyle.txt", "austen.txt", "twain.txt", "dickens.txt"], "name": "twain.txt"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
# austen.txt ['their', 'journey', 'was', 'performed', 'without', 'much', 'conversation,', 'or', 'any', 'alarm;', 'and']
# <div id="b74d2621-170e-4aa1-9669-2b4ec9bd3659" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b74d2621-170e-4aa1-9669-2b4ec9bd3659", [{"y": [3.397607244806579e-41, 2.5945831025482623e-51, 7.271589509739837e-47, 1.146057580937033e-50, 4.445717397913393e-47], "type": "scatter", "x": ["tolstoy.txt", "doyle.txt", "austen.txt", "twain.txt", "dickens.txt"], "name": "austen.txt"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
# dickens.txt ['was', 'when', 'i', 'ascended', 'it.']
# <div id="c7bd6480-4cde-4b63-85df-a1d7f1623326" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c7bd6480-4cde-4b63-85df-a1d7f1623326", [{"y": [4.340467890046653e-17, 2.3588545988587208e-20, 3.1194354198475695e-20, 2.6948380545844866e-20, 2.0777604043904826e-18], "type": "scatter", "x": ["tolstoy.txt", "doyle.txt", "austen.txt", "twain.txt", "dickens.txt"], "name": "dickens.txt"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
import numpy
import random

# %%
def generate():
    sentence_len = random.randrange(3, 15)
    class_counts = numpy.random.multinomial(sentence_len, list(cprobs.values()))
    word_classes = [i for i,x in enumerate(class_counts) for y in range(x)]
    random.shuffle(word_classes)
    print(class_counts, word_classes)
    for cls in word_classes:
        #print(cls, list(cprobs.keys()))
        cname = list(cprobs.keys())[cls - 1]        
        W = numpy.random.multinomial(10, list(uprobs[cname].values()))
        windex = numpy.argmax(W)
        wrd = list(uprobs[cname].keys())[windex]
        print("{wrd}/{cname} ".format(**locals()), end='')

# %%
generate()
# Out:
# [0 3 1 1 0] [3, 1, 2, 1, 1]
# of/dickens.txt on/twain.txt dozen/tolstoy.txt come/twain.txt her/twain.txt

# %%
#import os
import kenlm

model_dir = 'models/'
models = {m : kenlm.Model(model_dir + m) for m in os.listdir(model_dir) if m.endswith('.bin')}
starting_sentence = "this is a"

for author, model in models.items():
    print(author, '{0}-gram model'.format(model.order))
    sc = model.score(starting_sentence)
    #print(sc)
    desired_length = 20
    current_len = len(starting_sentence.split(' '))
    for i in range(desired_length - current_len):
        wds = list(all_unigrams[author[:-4] + '.txt'].keys())
        probs = []
        for word in wds:
            candidate_sentence = starting_sentence + " " + word
            cs = model.score(candidate_sentence)
            probs.append(cs)
        idx = numpy.argmax(probs)
        print(idx)
